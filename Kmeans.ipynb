# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajaykumar-02/Machine-Learning-Algorithms-Projects/blob/main/Kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.datasets import make_blobs
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
X, y_true = make_blobs(n_samples=300, centers=3, cluster_std=0.60, random_state=42)

# %%
df = pd.DataFrame(X, columns=['x', 'y'])
df.head()
# Out:
#           x         y
# 0 -7.155244 -7.390016
# 1 -7.395875 -7.110843
# 2 -2.015671  8.281780
# 3  4.509270  2.632436
# 4 -8.102502 -7.484961

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(df)

# %%
Wcss = []
K_range = range(1,11)

# %%
for k in K_range:
    kmeans = KMeans(n_clusters=k , random_state=42)
    kmeans.fit(X_scaled)
    Wcss.append(kmeans.inertia_)

# %%
Wcss
# Out:
# [599.9999999999997,
#  178.65671614695478,
#  6.775066760799564,
#  5.767530252280139,
#  4.722401665493833,
#  4.344605803073936,
#  4.141728955615087,
#  3.2562398432313193,
#  2.9977535420822266,
#  2.5997714738604842]

# %%
plt.plot(K_range, Wcss , marker='o')

# %%
kmeans_final = KMeans(n_clusters=3, random_state=42)

# %%
cluster_labels = kmeans_final.fit_predict(X_scaled)

# %%
df ['cluster'] = cluster_labels

# %%
sns.scatterplot(x='x', y='y', hue='cluster', data=df)
# Out:
# <Axes: xlabel='x', ylabel='y'>
