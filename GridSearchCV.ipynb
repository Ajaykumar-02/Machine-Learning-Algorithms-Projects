# %% [markdown]
# <a href="https://colab.research.google.com/github/Ajaykumar-02/Machine-Learning-Algorithms-Projects/blob/main/GridSearchCV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
df = sns.load_dataset("iris")

# %%
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
from sklearn.model_selection import train_test_split

# %%
X = df.drop('species', axis=1)
y = df['species']

# %%
X_train, X_test, y_train, y_test = train_test_split(
X, y, test_size=0.33, random_state=42)

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
model_knn = KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.fit(X_train, y_train)
# Out:
# KNeighborsClassifier(n_neighbors=13)

# %%
model_knn.score(X_test, y_test)
# Out:
# 1.0

# %%
from sklearn.svm import SVC

# %%
model_svm = SVC(gamma='auto')

# %%
model_svm.fit(X_train, y_train)
# Out:
# SVC(gamma='auto')

# %%
model_svm.score(X_test, y_test)
# Out:
# 1.0

# %%
# now lets use the grid search CV

# %%
from sklearn.model_selection import GridSearchCV

# %%
# We Use SVM Model

# %%
classifier = GridSearchCV((model_svm),{
    'C':[1,10,20,30],
    'kernel':['rbf','linear'],
},cv=5,return_train_score=False)

# %%
classifier.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=SVC(gamma='auto'),
#              param_grid={'C': [1, 10, 20, 30], 'kernel': ['rbf', 'linear']})

# %%
classifier.cv_results_
# Out:
# {'mean_fit_time': array([0.0056066 , 0.00385303, 0.00442281, 0.00377378, 0.00385861,
#         0.00368004, 0.00388494, 0.00563407]),
#  'std_fit_time': array([1.74986325e-03, 7.16620415e-05, 7.38809262e-04, 1.21399650e-04,
#         1.31214929e-04, 1.13991949e-04, 3.18885704e-04, 2.34764576e-03]),
#  'mean_score_time': array([0.00326152, 0.00300226, 0.00334444, 0.00289526, 0.00289488,
#         0.00339856, 0.00265503, 0.00431738]),
#  'std_score_time': array([3.21689890e-04, 3.69746389e-04, 9.60146656e-04, 4.94134455e-05,
#         2.42319289e-04, 1.09577012e-03, 2.25407487e-04, 1.66069551e-03]),
#  'param_C': masked_array(data=[1, 1, 10, 10, 20, 20, 30, 30],
#               mask=[False, False, False, False, False, False, False, False],
#         fill_value=999999),
#  'param_kernel': masked_array(data=['rbf', 'linear', 'rbf', 'linear', 'rbf', 'linear',
#                     'rbf', 'linear'],
#               mask=[False, False, False, False, False, False, False, False],
# ...

# %%
results = pd.DataFrame(classifier.cv_results_)

# %%
results
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  param_C  \
# 0       0.005607      0.001750         0.003262        0.000322        1
# 1       0.003853      0.000072         0.003002        0.000370        1
# 2       0.004423      0.000739         0.003344        0.000960       10
# 3       0.003774      0.000121         0.002895        0.000049       10
# 4       0.003859      0.000131         0.002895        0.000242       20
# 5       0.003680      0.000114         0.003399        0.001096       20
# 6       0.003885      0.000319         0.002655        0.000225       30
# 7       0.005634      0.002348         0.004317        0.001661       30
#
#   param_kernel                         params  split0_test_score  \
# 0          rbf      {'C': 1, 'kernel': 'rbf'}           0.966667
# 1       linear   {'C': 1, 'kernel': 'linear'}           0.966667
# 2          rbf     {'C': 10, 'kernel': 'rbf'}           0.966667
# ...

# %%
results[['param_C','param_kernel','mean_test_score']]
# Out:
#    param_C param_kernel  mean_test_score
# 0        1          rbf         0.980000
# 1        1       linear         0.980000
# 2       10          rbf         0.980000
# 3       10       linear         0.973333
# 4       20          rbf         0.966667
# 5       20       linear         0.966667
# 6       30          rbf         0.960000
# 7       30       linear         0.960000

# %%
# We use KNN Model

# %%
classifier_2 = GridSearchCV((model_knn),{
    'n_neighbors':[3,5,7,9,11],
     'weights':['uniform','distance'],
    'algorithm':['auto', 'ball_tree', 'kd_tree', 'brute'],

},cv = 5, return_train_score=False)

# %%
classifier_2.fit(X,y)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(n_neighbors=13),
#              param_grid={'algorithm': ['auto', 'ball_tree', 'kd_tree', 'brute'],
#                          'n_neighbors': [3, 5, 7, 9, 11],
#                          'weights': ['uniform', 'distance']})

# %%
classifier_2.cv_results_
# Out:
# {'mean_fit_time': array([0.00431256, 0.00420208, 0.0035759 , 0.00414753, 0.00393672,
#         0.00479007, 0.00357251, 0.00386624, 0.00356827, 0.00399966,
#         0.00354872, 0.00390329, 0.00395389, 0.00448656, 0.00347362,
#         0.00409937, 0.00390682, 0.00376668, 0.00368304, 0.00327144,
#         0.00343924, 0.00363579, 0.00353045, 0.00363631, 0.00352764,
#         0.00568695, 0.00331445, 0.00355883, 0.00343962, 0.00384965,
#         0.00332255, 0.00322704, 0.00314198, 0.00347414, 0.00320172,
#         0.00302734, 0.00314317, 0.00305905, 0.00308442, 0.00311832]),
#  'std_fit_time': array([7.59502798e-04, 1.22620429e-03, 1.19854573e-04, 1.25020520e-03,
#         7.93797871e-04, 1.05558050e-03, 2.70144322e-04, 2.67430557e-04,
#         1.62492545e-04, 9.31437164e-04, 1.78571957e-04, 3.88317386e-04,
#         5.17639656e-04, 1.68737864e-03, 2.44178806e-05, 6.68487823e-04,
#         1.40322943e-04, 7.50790062e-05, 4.45976604e-04, 6.46529645e-05,
# ...

# %%
results_knn = pd.DataFrame(classifier_2.cv_results_)

# %%
results_knn.head()
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0       0.004313      0.000760         0.005865        0.000805
# 1       0.004202      0.001226         0.004318        0.000605
# 2       0.003576      0.000120         0.005100        0.000217
# 3       0.004148      0.001250         0.003933        0.000058
# 4       0.003937      0.000794         0.006211        0.002688
#
#   param_algorithm  param_n_neighbors param_weights  \
# 0            auto                  3       uniform
# 1            auto                  3      distance
# 2            auto                  5       uniform
# 3            auto                  5      distance
# 4            auto                  7       uniform
#
#                                               params  split0_test_score  \
# 0  {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...           0.966667
# 1  {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...           0.966667
# ...

# %%
results_knn[['param_weights','param_n_neighbors','param_algorithm','mean_test_score']]
# Out:
#    param_weights  param_n_neighbors param_algorithm  mean_test_score
# 0        uniform                  3            auto         0.966667
# 1       distance                  3            auto         0.966667
# 2        uniform                  5            auto         0.973333
# 3       distance                  5            auto         0.966667
# 4        uniform                  7            auto         0.980000
# 5       distance                  7            auto         0.980000
# 6        uniform                  9            auto         0.973333
# 7       distance                  9            auto         0.973333
# 8        uniform                 11            auto         0.980000
# 9       distance                 11            auto         0.986667
# 10       uniform                  3       ball_tree         0.966667
# 11      distance                  3       ball_tree         0.966667
# 12       uniform                  5       ball_tree         0.973333
# ...
